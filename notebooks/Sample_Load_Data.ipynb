# %%
import sys
import urllib.request
import os
from google.cloud import bigquery

# %%
urllib.request.urlretrieve(url, './hult-hackathon-key.json')
# Out:
# ('./hult-hackathon-key.json', <http.client.HTTPMessage at 0x7f158a26f358>)

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = './hult-hackathon-key.json'

# %%
client = bigquery.Client()

# %%
QUERY = ('select * from `angostura_dev`.eh_health_survey_response')

df = client.query(QUERY).to_dataframe()

# %%
df.head()
# Out:
#                   timestamp  report_week operability_icu  \
# 0  2020-01-13T19:11:32.788Z  51 del 2019  Todos los días
# 1  2019-06-14T21:14:15.397Z  22 del 2019  Todos los días
# 2  2019-08-25T02:13:40.031Z  33 del 2019  Todos los días
# 3  2019-08-20T22:01:04.247Z  29 del 2019  Todos los días
# 4  2020-01-27T21:20:36.881Z   3 del 2020  Todos los días
#
#   power_outage_equipment_failure_specify  power_generator_available  \
# 0                                          Funciona menos de 3 días
# 1                                          Funciona menos de 3 días
# 2                                          Funciona menos de 3 días
# 3                                         Funciona entre 3 y 5 días
# 4                                          Funciona menos de 3 días
#
#   power_outage_mortatility  power_outage_deaths_count  \
# 0                       No                        NaN
# 1                       No                        NaN
# 2                       No                        0.0
# 3                       No                        NaN
# 4                       No                        NaN
#
#    mortality_hospital_failure_cardiovascular_count  \
# 0                                              0.0
# 1                                              1.0
# 2                                              0.0
# 3                                              0.0
# 4                                              2.0
#
#      mortality_hospital_failure_cardiovascular_cause  \
# 0
# 1              Equipos, Medicamentos, Recurso Humano
# 2
# 3
# 4  Equipos, Medicamentos, Recurso Humano, Resto e...
#
#    mortality_hospital_failure_trauma_count  ... er_staff_nurse_night_on_call  \
# 0                                      2.0  ...                            2
# 1                                      0.0  ...                            2
# 2                                      0.0  ...                            3
# 3                                      1.0  ...                            2
# 4                                      0.0  ...                            3
#
#   er_staff_non_professional_nurse_night_on_call  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
#
#                     wash_failure_icu                    wash_failure_er  \
# 0            No hubo agua ningún dia            No hubo agua ningún dia
# 1            No hubo agua ningún dia            No hubo agua ningún dia
# 2            No hubo agua ningún dia            No hubo agua ningún dia
# 3  3 a 5 días , sin soporte  alterno  3 a 5 días , sin soporte  alterno
# 4            No hubo agua ningún dia            No hubo agua ningún dia
#
#                      wahs_failure_sx power_outage  \
# 0            No hubo agua ningún dia           Si
# 1            No hubo agua ningún dia           Si
# 2            No hubo agua ningún dia           Si
# 3  3 a 5 días , sin soporte  alterno           Si
# 4            No hubo agua ningún dia           Si
#
#   power_outage_avg_failures_per_day power_outage_days_count  \
# 0                                 2        Entre 3 y 5 días
# 1                                 1        Entre 3 y 5 días
# 2                                 2        Entre 3 y 5 días
# 3                                 1         Menos de 3 días
# 4                                 2        Entre 3 y 5 días
#
#   power_outage_avg_duration power_outage_equipment_failure
# 0  1899-12-31T08:00:00.000Z                             No
# 1  1899-12-30T05:00:00.000Z                             No
# 2  1899-12-30T03:00:00.000Z                             No
# 3  1899-12-30T03:00:00.000Z                             No
# 4  1899-12-30T09:00:00.000Z                             No
#
# [5 rows x 121 columns]

# %%
print("Here are some quick details about the data:")
print(f">>  There are {len(df)} rows")
print(f">>  The shape of the df is {df.shape}")
# Out:
# Here are some quick details about the data:
# >>  There are 1001 rows
# >>  The shape of the df is (1001, 121)

# %%
df.groupby('hospital_code')['timestamp'].count()
# Out:
# hospital_code
# AMA000    37
# ANZ000    34
# APU000    27
# ARA001    35
# ARA002     9
# BAR000    37
# BOL000    51
# BOL001    17
# CAR000    28
# CAR001    26
# DCA000    37
# DCA001    10
# DCA002    34
# DCA003    33
# DCA004    32
# DCA005    41
# DCA006    38
# DCA007    22
# DEL000    39
# FAL000    39
# GUA000    38
# LAR000    12
# MER000    23
# MIR000    32
# MIR001     1
# MON000    33
# NES000    44
# POR000    34
# SUC000    38
# TAC000    31
# TAC001    31
# VAR000    37
# ZUL000     2
# ZUL001    19
# Name: timestamp, dtype: int64
